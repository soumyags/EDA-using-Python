# %%
import pandas as pd

# %%
from matplotlib import pyplot as pyplot
import seaborn as sns

# %%
df=pd.read_csv("Dubizzle Car Data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
df.head()
# Out:
#                                                title price_in_aed  kilometers  \
# 0                      MITSUBISHI PAJERO 3.5L / 2013       26,000      167390
# 1                                chevrolet silverado      110,000       39000
# 2  MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000      200000
# 3  WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000       27000
# 4                           USED RENAULT DOKKER 2020       33,000       69000
#
#            body_condition    mechanical_condition seller_type  \
# 0  Perfect inside and out  Perfect inside and out      Dealer
# 1  Perfect inside and out  Perfect inside and out      Dealer
# 2  Perfect inside and out  Perfect inside and out      Dealer
# 3  Perfect inside and out  Perfect inside and out      Dealer
# 4  Perfect inside and out  Perfect inside and out       Owner
#
#               body_type no_of_cylinders       transmission_type  \
# ...

# %%
df.shape
# Out:
# (9970, 20)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9889 non-null   object
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   float64
#  14  color                 9970 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 282

# %%
df.isna().sum()
# Out:
# title                     5
# price_in_aed              0
# kilometers                0
# body_condition            0
# mechanical_condition      0
# seller_type               0
# body_type                 0
# no_of_cylinders          81
# transmission_type         0
# regional_specs            0
# horsepower                0
# fuel_type                 0
# steering_side             0
# year                    970
# color                     0
# emirate                   0
# motors_trim              28
# company                   0
# model                     0
# date_posted               0
# dtype: int64

# %%
970/9970
# Out:
# 0.09729187562688064

# %%
df['body_condition'].value_counts()
# Out:
# body_condition
# Perfect inside and out                9612
# No accidents, very few faults          208
# A bit of wear & tear, all repaired     119
# Normal wear & tear, a few issues        31
# Name: count, dtype: int64

# %%
df['mechanical_condition'].value_counts()
# Out:
# mechanical_condition
# Perfect inside and out              9822
# Minor faults, all fixed              136
# Major faults fixed, small remain       8
# Ongoing minor & major faults           3
# Major faults, all fixed                1
# Name: count, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Dealer                            6762
# Owner                             2938
# Dealership/Certified Pre-Owned     270
# Name: count, dtype: int64

# %%
df['no_of_cylinders'].value_counts()
# Out:
# no_of_cylinders
# 6          3325
# 4          2993
# 8          2986
# 12          366
# Unknown      57
# 3            56
# 10           53
# 5            53
# Name: count, dtype: int64

# %%
df['year'].dtypes
# Out:
# dtype('float64')

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'])
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
# ...

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'],errors='coerce')

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('float64')

# %%
df['no_of_cylinders'].value_counts()
# Out:
# no_of_cylinders
# 6.0     3325
# 4.0     2993
# 8.0     2986
# 12.0     366
# 3.0       56
# 10.0      53
# 5.0       53
# Name: count, dtype: int64

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'])

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('float64')

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 138

# %%
mn=df['no_of_cylinders'].mean

# %%
mn
# Out:
# 6.221013018714402

# %%
md=df['no_of_cylinders'].median

# %%
md
# Out:
# <bound method Series.median of 0       6.0
# 1       8.0
# 2       6.0
# 3       8.0
# 4       4.0
#        ...
# 9965    8.0
# 9966    8.0
# 9967    8.0
# 9968    4.0
# 9969    6.0
# Name: no_of_cylinders, Length: 9970, dtype: float64>

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('float64')

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'])

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9832 non-null   float64
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   float64
#  14  color                 9970 non-null   object
# ...

# %%
df['no_of_cylinders']=df['no_of_cylinders'].astype('Int32')

# %%
df['no_of_cylinders'].dtype
# Out:
# Int32Dtype()

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 138

# %%
df['price_in_aed']=pd.to_numeric(df['price_in_aed'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "26,000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df['price_in_aed']=pd.to_numeric(df['price_in_aed'])
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
# ...

# %%
df['price_replace']=df['price_in_aed'].str.replace(',','')

# %%
df['price_replace']
# Out:
# 0        26000
# 1       110000
# 2        78000
# 3       899000
# 4        33000
#          ...
# 9965    215000
# 9966     90000
# 9967    679000
# 9968     18900
# 9969     77700
# Name: price_replace, Length: 9970, dtype: object

# %%
df['price_replace']=pd.to_numeric(df['price_replace'])

# %%
df['price_replace'].dtype
# Out:
# dtype('int64')

# %%
df['date_posted']=pd.to_datetime(df['date_posted'])
# Out:
# C:\Users\Soumya\AppData\Local\Temp\ipykernel_4472\2292659028.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date_posted']=pd.to_datetime(df['date_posted'])

# %%
df['date_posted'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9832 non-null   Int32
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   float64
#  14  color                 9970 non-null   object
# ...

# %%
df['price_in_aed']
# Out:
# 0        26,000
# 1       110,000
# 2        78,000
# 3       899,000
# 4        33,000
#          ...
# 9965    215,000
# 9966     90,000
# 9967    679,000
# 9968     18,900
# 9969     77,700
# Name: price_in_aed, Length: 9970, dtype: object

# %%
df['year']=pd.to_datetime(df['year'])

# %%
df['year'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9832 non-null   Int32
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   datetime64[ns]
# ...

# %%
df.columns
# Out:
# Index(['title', 'price_in_aed', 'kilometers', 'body_condition',
#        'mechanical_condition', 'seller_type', 'body_type', 'no_of_cylinders',
#        'transmission_type', 'regional_specs', 'horsepower', 'fuel_type',
#        'steering_side', 'year', 'color', 'emirate', 'motors_trim', 'company',
#        'model', 'date_posted', 'price_replace'],
#       dtype='object')

# %%
cat=df.columns[df.dtypes==object]

# %%
cat
# Out:
# Index(['title', 'price_in_aed', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'transmission_type', 'regional_specs',
#        'horsepower', 'fuel_type', 'steering_side', 'color', 'emirate',
#        'motors_trim', 'company', 'model'],
#       dtype='object')

# %%
df.drop('price_in_aed')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df.drop('price_in_aed')
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
# ...

# %%
df.drop(['price_in_aed'],axis=1)
# Out:
#                                                   title  kilometers  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                   chevrolet silverado       39000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                              USED RENAULT DOKKER 2020       69000
# ...                                                 ...         ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      105777
# 9966             LOW MILEAGE Cadillac Escalade Platinum       55640
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...         100
# 9968                         Chevrolet Malibu  GCC Spec      140000
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       86000
#
#                      body_condition    mechanical_condition seller_type  \
# 0            Perfect inside and out  Perfect inside and out      Dealer
# ...

# %%
df
# Out:
#                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9832 non-null   Int32
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   datetime64[ns]
# ...

# %%
cat
# Out:
# Index(['title', 'price_in_aed', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'transmission_type', 'regional_specs',
#        'horsepower', 'fuel_type', 'steering_side', 'color', 'emirate',
#        'motors_trim', 'company', 'model'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 cat['price_in_aed']
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\indexes\base.py:5416, in Index.__getitem__(self, key)
#    5407         if len(key) == 0 and len(key) != len(self):
#    5408             warnings.warn(
#    5409                 "Using a boolean indexer with length 0 on an Index with "
#    5410                 "length greater than 0 is deprecated and will raise in a "
#    (...)
#    5413                 stacklevel=find_stack_level(),
#    5414             )
# -> 5416 result = getitem(key)
#    5417 # Because we ruled out integer above, we always get an arraylike here
#    5418 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df.dtypes
# Out:
# title                           object
# price_in_aed                    object
# kilometers                       int64
# body_condition                  object
# mechanical_condition            object
# seller_type                     object
# body_type                       object
# no_of_cylinders                  Int32
# transmission_type               object
# regional_specs                  object
# horsepower                      object
# fuel_type                       object
# steering_side                   object
# year                    datetime64[ns]
# color                           object
# emirate                         object
# motors_trim                     object
# company                         object
# model                           object
# date_posted             datetime64[ns]
# price_replace                    int64
# dtype: object

# %%
df.drop('price_in_aed')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.drop('price_in_aed')
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
# ...

# %%
df.drop(columns=['price_in_aed'])
# Out:
#                                                   title  kilometers  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                   chevrolet silverado       39000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                              USED RENAULT DOKKER 2020       69000
# ...                                                 ...         ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      105777
# 9966             LOW MILEAGE Cadillac Escalade Platinum       55640
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...         100
# 9968                         Chevrolet Malibu  GCC Spec      140000
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       86000
#
#                      body_condition    mechanical_condition seller_type  \
# 0            Perfect inside and out  Perfect inside and out      Dealer
# ...

# %%
df
# Out:
#                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
df.columns
# Out:
# Index(['title', 'price_in_aed', 'kilometers', 'body_condition',
#        'mechanical_condition', 'seller_type', 'body_type', 'no_of_cylinders',
#        'transmission_type', 'regional_specs', 'horsepower', 'fuel_type',
#        'steering_side', 'year', 'color', 'emirate', 'motors_trim', 'company',
#        'model', 'date_posted', 'price_replace'],
#       dtype='object')

# %%
df.to_csv('test.csv')

# %%
df.drop('price_in_aed',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'kilometers', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'no_of_cylinders', 'transmission_type',
#        'regional_specs', 'horsepower', 'fuel_type', 'steering_side', 'year',
#        'color', 'emirate', 'motors_trim', 'company', 'model', 'date_posted',
#        'price_replace'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['title', 'kilometers', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'no_of_cylinders', 'transmission_type',
#        'regional_specs', 'horsepower', 'fuel_type', 'steering_side', 'year',
#        'color', 'emirate', 'motors_trim', 'company', 'model', 'date_posted',
#        'price_replace'],
#       dtype='object')

# %%
df.shape
# Out:
# (9970, 20)

# %%
df.dtypes
# Out:
# title                           object
# kilometers                       int64
# body_condition                  object
# mechanical_condition            object
# seller_type                     object
# body_type                       object
# no_of_cylinders                  Int32
# transmission_type               object
# regional_specs                  object
# horsepower                      object
# fuel_type                       object
# steering_side                   object
# year                    datetime64[ns]
# color                           object
# emirate                         object
# motors_trim                     object
# company                         object
# model                           object
# date_posted             datetime64[ns]
# price_replace                    int64
# dtype: object

# %%
cat=df.columns[df.dtypes==object]

# %%
cat
# Out:
# Index(['title', 'price_in_aed', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'no_of_cylinders', 'transmission_type',
#        'regional_specs', 'horsepower', 'fuel_type', 'steering_side', 'color',
#        'emirate', 'motors_trim', 'company', 'model', 'date_posted'],
#       dtype='object')

# %%
cat.dtype
# Out:
# dtype('O')

# %%
con=df.columns[df.dtypes!='object']

# %%
con
# Out:
# Index(['kilometers', 'year'], dtype='object')

# %% [markdown]
# Step2 :- Descriptive analysis

# %%
df.describe(cat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.describe(cat)
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\generic.py:11973, in NDFrame.describe(self, percentiles, include, exclude)
#   11731 @final
#   11732 def describe(
#   11733     self,
#    (...)
#   11736     exclude=None,
#   11737 ) -> Self:
#   11738     """
#   11739     Generate descriptive statistics.
#   11740
#    (...)
#   11971     max            NaN      3.0
#   11972     """
# > 11973     return describe_ndframe(
#   11974         obj=self,
#   11975         include=include,
#   11976         exclude=exclude,
#   11977         percentiles=percentiles,
#   11978     ).__finalize__(self, method="describe")
#
# ...

# %%
df.describe().T
# Out:
#                   count                           mean  \
# kilometers       9970.0                   98948.955366
# no_of_cylinders  9832.0                       6.221013
# year               9000  1970-01-01 00:00:00.000002015
# date_posted        9970     2022-03-28 14:26:18.655968
# price_replace    9970.0                  248049.577733
#
#                                            min                            25%  \
# kilometers                                 0.0                        23143.5
# no_of_cylinders                            3.0                            4.0
# year             1970-01-01 00:00:00.000001953  1970-01-01 00:00:00.000002014
# date_posted                2018-08-07 00:00:00            2022-03-16 00:00:00
# price_replace                           6000.0                        51000.0
#
#                                            50%                            75%  \
# kilometers                             76000.0                      133082.75
# ...

# %%
df[cat].describe().T
# Out:
#                      count unique                     top  freq
# title                 9965   9169           nissan patrol    77
# body_condition        9970      4  Perfect inside and out  9612
# mechanical_condition  9970      5  Perfect inside and out  9822
# seller_type           9970      3                  Dealer  6762
# body_type             9970     13                     SUV  4566
# transmission_type     9970      2  Automatic Transmission  9581
# regional_specs        9970      5               GCC Specs  7601
# horsepower            9970     11            200 - 300 HP  2432
# fuel_type             9970      4                Gasoline  9695
# steering_side         9970      2          Left Hand Side  9965
# color                 9970     17                   White  3333
# emirate               9970     16                   Dubai  7978
# motors_trim           9942    856                   Other  2175
# company               9970     73           mercedes-benz  1506
# ...

# %%
df[con].describe()
# Out:
#          kilometers  no_of_cylinders                           year  \
# count  9.970000e+03           9832.0                           9000
# mean   9.894896e+04         6.221013  1970-01-01 00:00:00.000002015
# min    0.000000e+00              3.0  1970-01-01 00:00:00.000001953
# 25%    2.314350e+04              4.0  1970-01-01 00:00:00.000002014
# 50%    7.600000e+04              6.0  1970-01-01 00:00:00.000002016
# 75%    1.330828e+05              8.0  1970-01-01 00:00:00.000002019
# max    1.150000e+08             12.0  1970-01-01 00:00:00.000002021
# std    1.154300e+06         1.966476                            NaN
#
#                       date_posted  price_replace
# count                        9970   9.970000e+03
# mean   2022-03-28 14:26:18.655968   2.480496e+05
# min           2018-08-07 00:00:00   6.000000e+03
# 25%           2022-03-16 00:00:00   5.100000e+04
# 50%           2022-04-19 00:00:00   1.040000e+05
# 75%           2022-05-07 00:00:00   2.340000e+05
# ...

# %% [markdown]
# EDA
# 1)Univrainte
# 2)Bivariante
# 3)Multovariante

# %%
Cat and con
********Univariante, used only 1 variable

cat: - use Pie chart and giechart
con :- Use Histogram

*******)Bivariante
con vs con---> For this we can use
scatterploe and corelation

con v/s cat ---> use Box plot 
& crosstab

chart :- ;l.////////////////////////////////////////////////////////////////////////////////////////////////// q

for Multivariant
use pairplot


con
# Out:
#   Cell In[115], line 7
#     *******)Bivariante
#            ^
# SyntaxError: unmatched ')'

# %% [markdown]
# Univariante analysis
# categorical - > Use Histogram or Piechart

# %%
df[cat]
# Out:
#                                                   title  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013
# 1                                   chevrolet silverado
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...
# 4                              USED RENAULT DOKKER 2020
# ...                                                 ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...
# 9966             LOW MILEAGE Cadillac Escalade Platinum
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...
# 9968                         Chevrolet Malibu  GCC Spec
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...
#
#                      body_condition    mechanical_condition seller_type  \
# 0            Perfect inside and out  Perfect inside and out      Dealer
# 1            Perfect inside and out  Perfect inside and out      Dealer
# 2            Perfect inside and out  Perfect inside and out      Dealer
# ...

# %%
df[cat].columns
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
df
# Out:
#                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
import seaborn as sns

# %%
df[cat].columns
# Out:
# Index(['title', 'price_in_aed', 'body_condition', 'mechanical_condition',
#        'seller_type', 'body_type', 'no_of_cylinders', 'transmission_type',
#        'regional_specs', 'horsepower', 'fuel_type', 'steering_side', 'color',
#        'emirate', 'motors_trim', 'company', 'model', 'date_posted'],
#       dtype='object')

# %%
df[cat].dtypes
# Out:
# title                   object
# price_in_aed            object
# body_condition          object
# mechanical_condition    object
# seller_type             object
# body_type               object
# no_of_cylinders         object
# transmission_type       object
# regional_specs          object
# horsepower              object
# fuel_type               object
# steering_side           object
# color                   object
# emirate                 object
# motors_trim             object
# company                 object
# model                   object
# date_posted             object
# dtype: object

# %%
df[con].dtypes
# Out:
# kilometers      int64
# year          float64
# dtype: object

# %%
pd.to_datetime(df['date_posted'])
# Out:
# C:\Users\Soumya\AppData\Local\Temp\ipykernel_19188\3341124585.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(df['date_posted'])
# 0      2022-05-13
# 1      2022-01-14
# 2      2022-05-05
# 3      2022-04-30
# 4      2022-05-13
#           ...
# 9965   2021-11-18
# 9966   2022-05-11
# 9967   2021-12-14
# 9968   2022-03-06
# 9969   2021-12-04
# Name: date_posted, Length: 9970, dtype: datetime64[ns]

# %%
pd.to_numeric(df['no_of_cylinders'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 pd.to_numeric(df['no_of_cylinders'])
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
# ...

# %%
pd.to_numeric(df['no_of_cylinders'],errors='coerce')
# Out:
# 0       6.0
# 1       8.0
# 2       6.0
# 3       8.0
# 4       4.0
#        ...
# 9965    8.0
# 9966    8.0
# 9967    8.0
# 9968    4.0
# 9969    6.0
# Name: no_of_cylinders, Length: 9970, dtype: float64

# %%
df.to_csv('test.csv')

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
pd.to_numeric(df['no_of_cylinders'],errors='coerce')
# Out:
# 0       6.0
# 1       8.0
# 2       6.0
# 3       8.0
# 4       4.0
#        ...
# 9965    8.0
# 9966    8.0
# 9967    8.0
# 9968    4.0
# 9969    6.0
# Name: no_of_cylinders, Length: 9970, dtype: float64

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
df['no_of_cylinders'].astype='Int32'

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
df.columns
# Out:
# Index(['title', 'price_in_aed', 'kilometers', 'body_condition',
#        'mechanical_condition', 'seller_type', 'body_type', 'no_of_cylinders',
#        'transmission_type', 'regional_specs', 'horsepower', 'fuel_type',
#        'steering_side', 'year', 'color', 'emirate', 'motors_trim', 'company',
#        'model', 'date_posted'],
#       dtype='object')

# %%
df.shape
# Out:
# (9970, 20)

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
df
# Out:
#                                                   title price_in_aed  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013       26,000
# 1                                   chevrolet silverado      110,000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...       78,000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...      899,000
# 4                              USED RENAULT DOKKER 2020       33,000
# ...                                                 ...          ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# ...

# %%
df=pd.read_csv('Dubizzle Car Data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv('Dubizzle Car Data.csv')
#
# NameError: name 'pd' is not defined

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'],errors='coerce')

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('float64')

# %%
df['no_of_cylinders']=df['no_of_cylinders'].astype='Int32'

# %%
df['no_of_cylinders'].dtypes
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# title                    object
# price_in_aed             object
# kilometers                int64
# body_condition           object
# mechanical_condition     object
# seller_type              object
# body_type                object
# no_of_cylinders          object
# transmission_type        object
# regional_specs           object
# horsepower               object
# fuel_type                object
# steering_side            object
# year                    float64
# color                    object
# emirate                  object
# motors_trim              object
# company                  object
# model                    object
# date_posted              object
# dtype: object

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('O')

# %%
df['year']=pd.to_datetime(df['year'])

# %%
df['year'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# title                           object
# price_in_aed                    object
# kilometers                       int64
# body_condition                  object
# mechanical_condition            object
# seller_type                     object
# body_type                       object
# no_of_cylinders                 object
# transmission_type               object
# regional_specs                  object
# horsepower                      object
# fuel_type                       object
# steering_side                   object
# year                    datetime64[ns]
# color                           object
# emirate                         object
# motors_trim                     object
# company                         object
# model                           object
# date_posted                     object
# dtype: object

# %%
df['date_posted']=pd.to_datetime(df['date_posted'])
# Out:
# C:\Users\Soumya\AppData\Local\Temp\ipykernel_31596\2292659028.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['date_posted']=pd.to_datetime(df['date_posted'])

# %%
df['date_posted'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['no_of_cylinders']=df['no_of_cylinders'].astype='Int64'

# %%
df.dtypes
# Out:
# title                           object
# price_in_aed                    object
# kilometers                       int64
# body_condition                  object
# mechanical_condition            object
# seller_type                     object
# body_type                       object
# no_of_cylinders                 object
# transmission_type               object
# regional_specs                  object
# horsepower                      object
# fuel_type                       object
# steering_side                   object
# year                    datetime64[ns]
# color                           object
# emirate                         object
# motors_trim                     object
# company                         object
# model                           object
# date_posted             datetime64[ns]
# dtype: object

# %%
price_in_AED=df['price_in_aed'].str.replace(',','')

# %%
df['price_in_AED']=price_in_AED

# %%
df['price_in_AED']
# Out:
# 0        26000
# 1       110000
# 2        78000
# 3       899000
# 4        33000
#          ...
# 9965    215000
# 9966     90000
# 9967    679000
# 9968     18900
# 9969     77700
# Name: price_in_AED, Length: 9970, dtype: object

# %%
df['price_in_AED']=pd.to_numeric(df['price_in_AED'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9970 non-null   object
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   datetime64[ns]
# ...

# %%
df['C']=df['price_in_aed']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   object
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9970 non-null   object
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   datetime64[ns]
# ...

# %%
df.drop(['price_in_aed','C'],axis=1,inplace=True)

# %%
df
# Out:
#                                                   title  kilometers  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                   chevrolet silverado       39000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                              USED RENAULT DOKKER 2020       69000
# ...                                                 ...         ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      105777
# 9966             LOW MILEAGE Cadillac Escalade Platinum       55640
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...         100
# 9968                         Chevrolet Malibu  GCC Spec      140000
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       86000
#
#                      body_condition    mechanical_condition seller_type  \
# 0            Perfect inside and out  Perfect inside and out      Dealer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   kilometers            9970 non-null   int64
#  2   body_condition        9970 non-null   object
#  3   mechanical_condition  9970 non-null   object
#  4   seller_type           9970 non-null   object
#  5   body_type             9970 non-null   object
#  6   no_of_cylinders       9970 non-null   object
#  7   transmission_type     9970 non-null   object
#  8   regional_specs        9970 non-null   object
#  9   horsepower            9970 non-null   object
#  10  fuel_type             9970 non-null   object
#  11  steering_side         9970 non-null   object
#  12  year                  9000 non-null   datetime64[ns]
#  13  color                 9970 non-null   object
# ...

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   kilometers            9970 non-null   int64
#  2   body_condition        9970 non-null   object
#  3   mechanical_condition  9970 non-null   object
#  4   seller_type           9970 non-null   object
#  5   body_type             9970 non-null   object
#  6   no_of_cylinders       0 non-null      float64
#  7   transmission_type     9970 non-null   object
#  8   regional_specs        9970 non-null   object
#  9   horsepower            9970 non-null   object
#  10  fuel_type             9970 non-null   object
#  11  steering_side         9970 non-null   object
#  12  year                  9000 non-null   datetime64[ns]
#  13  color                 9970 non-null   object
# ...

# %%
cat=df.columns[df.dtypes==object]

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
cat.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 cat.info()
#
# AttributeError: 'Index' object has no attribute 'info'

# %%
df['cat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['cat']
#
# ...

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
con=df.columns[df.dtypes!='object']

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
sns.histplot(data=df,x='seller_type')
# Out:
# <Axes: xlabel='seller_type', ylabel='Count'>

# %%
sns.piechart(data=df,x='emirates')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sns.piechart(data=df,x='emirates')
#
# AttributeError: module 'seaborn' has no attribute 'piechart'

# %%
df['emirate'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='emirate'>

# %%
df['fuel_type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(data=df,x='price_in_AED')
# Out:
# <Axes: xlabel='price_in_AED', ylabel='Count'>

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
df['model'].value_counts()
# Out:
# model
# patrol               399
# s-class              269
# g-class              259
# range-rover-sport    208
# land-cruiser         200
#                     ...
# g80                    1
# plus-8                 1
# lc-500                 1
# tx5                    1
# odyssey-j              1
# Name: count, Length: 552, dtype: int64

# %%
df['company'].value_counts()
# Out:
# company
# mercedes-benz    1506
# nissan            898
# toyota            868
# bmw               690
# land-rover        577
#                  ...
# jac                 1
# levc                1
# buick               1
# foton               1
# maxus               1
# Name: count, Length: 73, dtype: int64

# %%
df[cat].describe().T
# Out:
#                      count unique                     top  freq
# title                 9965   9169           nissan patrol    77
# body_condition        9970      4  Perfect inside and out  9612
# mechanical_condition  9970      5  Perfect inside and out  9822
# seller_type           9970      3                  Dealer  6762
# body_type             9970     13                     SUV  4566
# transmission_type     9970      2  Automatic Transmission  9581
# regional_specs        9970      5               GCC Specs  7601
# horsepower            9970     11            200 - 300 HP  2432
# fuel_type             9970      4                Gasoline  9695
# steering_side         9970      2          Left Hand Side  9965
# color                 9970     17                   White  3333
# emirate               9970     16                   Dubai  7978
# motors_trim           9942    856                   Other  2175
# company               9970     73           mercedes-benz  1506
# ...

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                   title  kilometers  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                   chevrolet silverado       39000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                              USED RENAULT DOKKER 2020       69000
# ...                                                 ...         ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      105777
# 9966             LOW MILEAGE Cadillac Escalade Platinum       55640
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...         100
# 9968                         Chevrolet Malibu  GCC Spec      140000
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       86000
#
#                      body_condition    mechanical_condition seller_type  \
# ...

# %%
df.head()
# Out:
#                                                title  kilometers  \
# 0                      MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                chevrolet silverado       39000
# 2  MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3  WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                           USED RENAULT DOKKER 2020       69000
#
#            body_condition    mechanical_condition seller_type  \
# 0  Perfect inside and out  Perfect inside and out      Dealer
# 1  Perfect inside and out  Perfect inside and out      Dealer
# 2  Perfect inside and out  Perfect inside and out      Dealer
# 3  Perfect inside and out  Perfect inside and out      Dealer
# 4  Perfect inside and out  Perfect inside and out       Owner
#
#               body_type  no_of_cylinders       transmission_type  \
# 0                   SUV              NaN  Automatic Transmission
# 1                   SUV              NaN  Automatic Transmission
# ...

# %%
df.tail(5)
# Out:
#                                                   title price_in_aed  \
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      215,000
# 9966             LOW MILEAGE Cadillac Escalade Platinum       90,000
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...      679,000
# 9968                         Chevrolet Malibu  GCC Spec       18,900
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       77,700
#
#       kilometers                 body_condition    mechanical_condition  \
# 9965      105777         Perfect inside and out  Perfect inside and out
# 9966       55640         Perfect inside and out  Perfect inside and out
# 9967         100         Perfect inside and out  Perfect inside and out
# 9968      140000  No accidents, very few faults  Perfect inside and out
# 9969       86000         Perfect inside and out  Perfect inside and out
#
#      seller_type  body_type no_of_cylinders       transmission_type  \
# ...

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.histplot(data=df,x='no_of_cylinders')
# Out:
# <Axes: xlabel='no_of_cylinders', ylabel='Count'>

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 9970

# %%
pd.to_csv(df['no_of_cylinders'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 pd.to_csv(df['no_of_cylinders'])
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
df['price_in_AED'].isna().sum()
# Out:
# 0

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 9970

# %%
df1=pd.read_csv('Cylin.csv')

# %%
df1.dtypes
# Out:
# no_of_cylinders    object
# dtype: object

# %%
df.append
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31596\202388049.py in ?()
# ----> 1 df.append(df1)
#
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df['no_of_cylinders']=df1['no_of_cylinders']

# %%
df['no_of_cylinders']
# Out:
# 0         6
# 1         8
# 2         6
# 3         8
# 4         4
#        ...
# 9965    NaN
# 9966    NaN
# 9967    NaN
# 9968    NaN
# 9969    NaN
# Name: no_of_cylinders, Length: 9970, dtype: object

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 81

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
con.T
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
df.dtypes
# Out:
# title                           object
# kilometers                       int64
# body_condition                  object
# mechanical_condition            object
# seller_type                     object
# body_type                       object
# no_of_cylinders                 object
# transmission_type               object
# regional_specs                  object
# horsepower                      object
# fuel_type                       object
# steering_side                   object
# year                    datetime64[ns]
# color                           object
# emirate                         object
# motors_trim                     object
# company                         object
# model                           object
# date_posted             datetime64[ns]
# price_in_AED                     int64
# dtype: object

# %%
for i in con:
    print(df[i])
# Out:
# 0       167390
# 1        39000
# 2       200000
# 3        27000
# 4        69000
#          ...
# 9965    105777
# 9966     55640
# 9967       100
# 9968    140000
# 9969     86000
# Name: kilometers, Length: 9970, dtype: int64
# 0         6
# 1         8
# 2         6
# 3         8
# 4         4
#        ...
# 9965    NaN
# 9966    NaN
# 9967    NaN
# 9968    NaN
# 9969    NaN
# Name: no_of_cylinders, Length: 9970, dtype: object
# 0      1970-01-01 00:00:00.000002013
# 1      1970-01-01 00:00:00.000002018
# 2      1970-01-01 00:00:00.000002014
# 3      1970-01-01 00:00:00.000002018
# 4      1970-01-01 00:00:00.000002020
#                     ...
# 9965   1970-01-01 00:00:00.000002015
# 9966   1970-01-01 00:00:00.000002014
# 9967                             NaT
# 9968   1970-01-01 00:00:00.000002013
# 9969   1970-01-01 00:00:00.000002013
# Name: year, Length: 9970, dtype: datetime64[ns]
# 0      2022-05-13
# 1      2022-01-14
# 2      2022-05-05
# 3      2022-04-30
# ...

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'],errors='coerce')

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders           float64
# year               datetime64[ns]
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
df['no_of_cylinders']=df['no_of_cylinders'].astype='Int64'

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders            object
# year               datetime64[ns]
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders           float64
# year               datetime64[ns]
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 9970

# %%
df['no_of_cylinders']=df1['no_of_cylinders']

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 81

# %%
df['no_of_cylinders'].dtype
# Out:
# dtype('O')

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders            object
# year               datetime64[ns]
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
df['no_of_cylinders']=pd.to_numeric(df['no_of_cylinders'],errors='coerce')

# %%
df['no_of_cylinders'].isna().sum()
# Out:
# 138

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders           float64
# year               datetime64[ns]
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
from matplotlib import pyplot as plt

# %%
for i in con:
    plt.histplot(data=df,x=i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 2
#       1 for i in con:
# ----> 2     plt.histplot(data=df,x=i)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histplot'

# %%
df['no_of_cylinders'].value_counts()
# Out:
# no_of_cylinders
# 6.0     3325
# 4.0     2993
# 8.0     2986
# 12.0     366
# 3.0       56
# 10.0      53
# 5.0       53
# Name: count, dtype: int64

# %%
sns.histplot(data=df,x='no_of_cylinders',kde='True')
# Out:
# <Axes: xlabel='no_of_cylinders', ylabel='Count'>

# %%
df['no_of_cylinders'].value_counts()
# Out:
# no_of_cylinders
# 6.0     3325
# 4.0     2993
# 8.0     2986
# 12.0     366
# 3.0       56
# 10.0      53
# 5.0       53
# Name: count, dtype: int64

# %%
df['year']==2021
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9965    False
# 9966    False
# 9967    False
# 9968    False
# 9969    False
# Name: year, Length: 9970, dtype: bool

# %%
sns.histplot(data=df,x='year')
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
df['date_posted'].value_counts().sum()
# Out:
# 9970

# %%
    for i in con:
        sns.histplot(data=df,x=i)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000001B55FC45440> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# ...

# %%
for i in con:
    print(i)
# Out:
# kilometers
# no_of_cylinders
# year
# date_posted
# price_in_AED

# %%
for i in con:
    df[i].value_counts().plot(type='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[154], line 2
#       1 for i in con:
# ----> 2     df[i].value_counts().plot(type='bar')
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
df['color'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='color'>

# %%
for i in cat:
    df[i].value_counts().plot(kind='bar')
    plt.show()
# Out:
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# For Bivariante analysis
#
# 1)

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
sns.scatterplot(data=df,x='no_of_cylinders',y='price_in_AED')
# Out:
# <Axes: xlabel='no_of_cylinders', ylabel='price_in_AED'>

# %%
df['price_in_AED'].cross_tab()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31596\1617955956.py in ?()
# ----> 1 df['price_in_AED'].cross_tab()
#
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'cross_tab'

# %%
cor=df[con].corr()

# %%
cor
# Out:
#                  kilometers  no_of_cylinders      year  date_posted  \
# kilometers         1.000000         0.009022  0.027898     0.012176
# no_of_cylinders    0.009022         1.000000  0.005637    -0.024635
# year               0.027898         0.005637  1.000000     0.005947
# date_posted        0.012176        -0.024635  0.005947     1.000000
# price_in_AED      -0.028398        -0.000218 -0.353471    -0.072575
#
#                  price_in_AED
# kilometers          -0.028398
# no_of_cylinders     -0.000218
# year                -0.353471
# date_posted         -0.072575
# price_in_AED         1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
sns.boxplot(data=df,x='seller_type',y='no_of_cylinders')
plt.show()

# %%
for i in cat:
    sns.boxplot(data=df,x=i,y='price_in_AED')
    plt.show
# Out:
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
for i in cat:
    sns.boxplot(data=df,x=i,y='year')
    plt.show()
# Out:
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df1
# Out:
#      no_of_cylinders
# 0                  6
# 1                  8
# 2                  6
# 3                  8
# 4                  4
# ...              ...
# 9906               8
# 9907               8
# 9908               8
# 9909               4
# 9910               6
#
# [9911 rows x 1 columns]

# %%
df2=pd.read_csv('Dubizzle Car Data.csv')

# %%
df['year']=df2['year']

# %%
df2['year'].value_counts()
# Out:
# year
# 2016.0    973
# 2015.0    909
# 2019.0    903
# 2021.0    881
# 2018.0    859
# 2017.0    791
# 2020.0    781
# 2014.0    752
# 2013.0    603
# 2012.0    385
# 2011.0    252
# 2009.0    185
# 2008.0    178
# 2010.0    170
# 2007.0    103
# 2006.0     74
# 2005.0     54
# 2004.0     29
# 2001.0     18
# 2003.0     15
# 2002.0     11
# 2000.0     10
# 1999.0      9
# 1989.0      6
# 1998.0      6
# 1990.0      3
# 1983.0      3
# 1997.0      3
# 1991.0      3
# 1971.0      2
# 1980.0      2
# 1964.0      2
# 1965.0      2
# 1992.0      2
# 1994.0      2
# 1973.0      2
# 1987.0      2
# 1976.0      1
# 1996.0      1
# 1984.0      1
# 1977.0      1
# 1972.0      1
# 1979.0      1
# 1954.0      1
# 1953.0      1
# 1995.0      1
# 1974.0      1
# 1969.0      1
# 1975.0      1
# 1982.0      1
# 1960.0      1
# 1970.0      1
# Name: count, dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2016.0    973
# 2015.0    909
# 2019.0    903
# 2021.0    881
# 2018.0    859
# 2017.0    791
# 2020.0    781
# 2014.0    752
# 2013.0    603
# 2012.0    385
# 2011.0    252
# 2009.0    185
# 2008.0    178
# 2010.0    170
# 2007.0    103
# 2006.0     74
# 2005.0     54
# 2004.0     29
# 2001.0     18
# 2003.0     15
# 2002.0     11
# 2000.0     10
# 1999.0      9
# 1989.0      6
# 1998.0      6
# 1990.0      3
# 1983.0      3
# 1997.0      3
# 1991.0      3
# 1971.0      2
# 1980.0      2
# 1964.0      2
# 1965.0      2
# 1992.0      2
# 1994.0      2
# 1973.0      2
# 1987.0      2
# 1976.0      1
# 1996.0      1
# 1984.0      1
# 1977.0      1
# 1972.0      1
# 1979.0      1
# 1954.0      1
# 1953.0      1
# 1995.0      1
# 1974.0      1
# 1969.0      1
# 1975.0      1
# 1982.0      1
# 1960.0      1
# 1970.0      1
# Name: count, dtype: int64

# %%
df.groupby(by='year').count()[:10]['price_in_AED']
# Out:
# C:\Users\Soumya\AppData\Local\Temp\ipykernel_31596\4150409823.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   df.groupby(by='year').count()[:10]['price_in_AED']
# Series([], Name: price_in_AED, dtype: int64)

# %%
df['year'][::-1]
# Out:
# 9969    2013.0
# 9968    2013.0
# 9967       NaN
# 9966    2014.0
# 9965    2015.0
#          ...
# 4       2020.0
# 3       2018.0
# 2       2014.0
# 1       2018.0
# 0       2013.0
# Name: year, Length: 9970, dtype: float64

# %%
df['year'].dtypes
# Out:
# dtype('float64')

# %%
df['year'][:20]
# Out:
# 0     2013.0
# 1     2018.0
# 2     2014.0
# 3     2018.0
# 4     2020.0
# 5     2015.0
# 6     2019.0
# 7        NaN
# 8        NaN
# 9     2013.0
# 10    2020.0
# 11    2020.0
# 12    2019.0
# 13       NaN
# 14    2008.0
# 15    2018.0
# 16    2020.0
# 17       NaN
# 18    2018.0
# 19    2018.0
# Name: year, dtype: float64

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
df[con].value_counts()
# Out:
# kilometers  no_of_cylinders  year    date_posted  price_in_AED
# 93400       8.0              2008.0  2022-05-13   22500           2
# 146160      4.0              2018.0  2022-03-23   299890          2
# 126716      6.0              2015.0  2022-05-11   55000           2
# 120000      4.0              2016.0  2022-04-25   50000           2
# 31000       4.0              2019.0  2022-02-24   183000          2
#                                                                  ..
# 55000       8.0              2015.0  2022-02-24   189900          1
#             6.0              2020.0  2022-05-13   75000           1
#                                      2022-04-26   745000          1
#                              2019.0  2022-04-27   85000           1
# 115000000   8.0              2006.0  2022-05-06   112000          1
# Name: count, Length: 8812, dtype: int64

# %%
for i in cat:
    sns.histplot(data=df,x=i,y='year')
    plt.show()
# Out:
# c:\Users\Soumya\Regression Project\repository\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['transmission_type'].value_counts()
# Out:
# transmission_type
# Automatic Transmission    9581
# Manual Transmission        389
# Name: count, dtype: int64

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
cr=pd.crosstab(df['seller_type'],df['company'])

# %%
cr.T
# Out:
# seller_type           Dealer  Dealership/Certified Pre-Owned  Owner
# company
# acura                      2                               0      0
# alfa-romeo                17                               0      5
# aston-martin              26                               0      6
# audi                     238                              27    116
# baic                       0                               0      2
# ...                      ...                             ...    ...
# tesla                     23                               0     13
# toyota                   621                               6    241
# volkswagen               144                               3     75
# volvo                     19                               0      7
# westfield-sportscars       1                               0      0
#
# [73 rows x 3 columns]

# %%
sns.heatmap(cr,annot=True)
# Out:
# <Axes: xlabel='company', ylabel='seller_type'>

# %%
cr=pd.crosstab(df['seller_type'],df['body_condition'])

# %%
cr
# Out:
# body_condition                  A bit of wear & tear, all repaired  \
# seller_type
# Dealer                                                           1
# Dealership/Certified Pre-Owned                                  25
# Owner                                                           93
#
# body_condition                  No accidents, very few faults  \
# seller_type
# Dealer                                                     19
# Dealership/Certified Pre-Owned                              4
# Owner                                                     185
#
# body_condition                  Normal wear & tear, a few issues  \
# seller_type
# Dealer                                                         1
# Dealership/Certified Pre-Owned                                 0
# Owner                                                         30
#
# body_condition                  Perfect inside and out
# seller_type
# Dealer                                            6741
# ...

# %%
sns.heatmap(cr,annot=True)
# Out:
# <Axes: xlabel='body_condition', ylabel='seller_type'>

# %%
cr1=pd.crosstab(df['body_type'],['body_condition'])

# %%
cr1
# Out:
# col_0                 body_condition
# body_type
# Coupe                            851
# Crossover                        114
# Hard Top Convertible             162
# Hatchback                        344
# Other                            102
# Pick Up Truck                    428
# SUV                             4566
# Sedan                           2748
# Soft Top Convertible             142
# Sports Car                       260
# Utility Truck                     25
# Van                              162
# Wagon                             66

# %%
sns.heatmap(cr1,annot=True,fmt='d')
# Out:
# <Axes: xlabel='col_0', ylabel='body_type'>

# %%
df['body_condition'].value_counts()
# Out:
# body_condition
# Perfect inside and out                9612
# No accidents, very few faults          208
# A bit of wear & tear, all repaired     119
# Normal wear & tear, a few issues        31
# Name: count, dtype: int64

# %% [markdown]
# Multivariant Analysis

# %%
df
# Out:
#                                                   title  kilometers  \
# 0                         MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                   chevrolet silverado       39000
# 2     MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3     WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                              USED RENAULT DOKKER 2020       69000
# ...                                                 ...         ...
# 9965  AED7525month | 2015 Land Rover Range Rover Aut...      105777
# 9966             LOW MILEAGE Cadillac Escalade Platinum       55640
# 9967  WARRANTY AVAILABLE || Range Rover Sport SVR Ca...         100
# 9968                         Chevrolet Malibu  GCC Spec      140000
# 9969  LOW MILEAGE! PERFECT CONDITION! Jeep Wrangler ...       86000
#
#                      body_condition    mechanical_condition seller_type  \
# 0            Perfect inside and out  Perfect inside and out      Dealer
# ...

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
m=df['date_posted'].dt.year

# %%
m
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 9965    2021
# 9966    2022
# 9967    2021
# 9968    2022
# 9969    2021
# Name: date_posted, Length: 9970, dtype: int32

# %%
df['date_posted'].dt.day
# Out:
# 0       13
# 1       14
# 2        5
# 3       30
# 4       13
#         ..
# 9965    18
# 9966    11
# 9967    14
# 9968     6
# 9969     4
# Name: date_posted, Length: 9970, dtype: int32

# %% [markdown]
# display the year where maximum models are uploaded

# %%
df.groupby(by=df['date_posted'].dt.year)['model'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='date_posted'>

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
df['company'].value_counts()[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
df.groupby(by='company').count()[:10]['fuel_type'].plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
m=df.groupby(by='regional_specs').count()['fuel_type'].plot(kind='bar',y='fuel_type')

# %%
m
# Out:
# regional_specs
# European Specs           422
# GCC Specs               7601
# Japanese Specs           249
# North American Specs    1147
# Other                    551
# Name: fuel_type, dtype: int64

# %%
cat
# Out:
# Index(['title', 'body_condition', 'mechanical_condition', 'seller_type',
#        'body_type', 'transmission_type', 'regional_specs', 'horsepower',
#        'fuel_type', 'steering_side', 'color', 'emirate', 'motors_trim',
#        'company', 'model'],
#       dtype='object')

# %%
con
# Out:
# Index(['kilometers', 'no_of_cylinders', 'year', 'date_posted', 'price_in_AED'], dtype='object')

# %%
df['year']
# Out:
# 0       2013.0
# 1       2018.0
# 2       2014.0
# 3       2018.0
# 4       2020.0
#          ...
# 9965    2015.0
# 9966    2014.0
# 9967       NaN
# 9968    2013.0
# 9969    2013.0
# Name: year, Length: 9970, dtype: float64

# %%
df[con].dtypes
# Out:
# kilometers                  int64
# no_of_cylinders           float64
# year                      float64
# date_posted        datetime64[ns]
# price_in_AED                int64
# dtype: object

# %%
df.groupby(by=k).count()['price_in_AED']
# Out:
# year
# 1970.0    9000
# Name: price_in_AED, dtype: int64

# %% [markdown]
# Multivariant Analysis

# %%
df.head()
# Out:
#                                                title  kilometers  \
# 0                      MITSUBISHI PAJERO 3.5L / 2013      167390
# 1                                chevrolet silverado       39000
# 2  MERCEDES-BENZ E300 - 2014 - GCC SPEC - FULL OP...      200000
# 3  WARRANTY UNTIL APR 2023 || Ferrari 488 Spider ...       27000
# 4                           USED RENAULT DOKKER 2020       69000
#
#            body_condition    mechanical_condition seller_type  \
# 0  Perfect inside and out  Perfect inside and out      Dealer
# 1  Perfect inside and out  Perfect inside and out      Dealer
# 2  Perfect inside and out  Perfect inside and out      Dealer
# 3  Perfect inside and out  Perfect inside and out      Dealer
# 4  Perfect inside and out  Perfect inside and out       Owner
#
#               body_type  no_of_cylinders       transmission_type  \
# 0                   SUV              6.0  Automatic Transmission
# 1                   SUV              8.0  Automatic Transmission
# ...

# %%
sns.pairplot(df)
